# %% [markdown]
# git config --global user.name "Maksim Pchelkin"
#
# git config --global user.email maksim.dvl@yandex.ru
#
# git config --list

# %% [markdown]
# Инициализация пустого репозитория:
#
# git init
#
# ls -la

# %% [markdown]
# staging area(index): git status

# %% [markdown]
# git add - добавляет файлы в индекс
#
# git add App.js
#
# git add .
#
# git commit -m "message"- сохранение изменений
#
# git commit -a - добавление и коммит
#
# git checkout - переход на коммит в рабочей директории
